# %%
import numpy as np
import pandas as pd

# %%
bjp = pd.read_csv('new_bjp_all.csv')
ncp = pd.read_csv('new_ncp_all.csv')

# %%
bjp.sort_values('retweets', ascending=False, inplace=True)

# %%
bjp.head()
# Out:
#                                            cleaned_text           created_at  \
# 1606  私は結婚して、10年ほど経つが、 子供はいない。 「子供がいないで、楽なんだよ」 と、言われ...  2019-02-02 23:41:30
# 510       Nobody: Me at 12am on February 1st every year  2019-02-01 23:59:38
# 1186  eiiii migos eu e meu namo moramos juntos e rec...  2019-02-06 23:55:05
# 1176  eiiii migos eu e meu namo moramos juntos e rec...  2019-02-06 23:56:06
# 1180  eiiii migos eu e meu namo moramos juntos e rec...  2019-02-06 23:55:47
#
#       follower_count                                      profile_image  \
# 1606            1619  https://pbs.twimg.com/profile_images/109364140...
# 510              134  https://pbs.twimg.com/profile_images/105806996...
# 1186            2355  https://pbs.twimg.com/profile_images/109365471...
# 1176             250  https://pbs.twimg.com/profile_images/108068812...
# 1180             249  https://pbs.twimg.com/profile_images/108017477...
#
# ...

# %%
bjp = bjp[bjp['retweets']!= 16771]

# %%
bjp = bjp[bjp['retweets']!= 45364]

# %%
new_bjp = bjp.drop_duplicates('retweets')[:10]

# %%
new_bjp.to_csv('bjp_show.csv', index=False)

# %%
pd.read_csv('bjp_show.csv')
# Out:
#                                         cleaned_text           created_at  \
# 0      Nobody: Me at 12am on February 1st every year  2019-02-01 23:59:38
# 1  I spoke with Mamata Di tonight and told her we...  2019-02-03 23:56:50
# 2  I thank the people of Jind for blessing This i...  2019-02-01 23:52:33
# 3  Pappu brought PG (Priyanka Gandhi Modi brought...  2019-02-01 23:57:13
# 4  Modi Government clears one more step to get Ma...  2019-02-04 23:55:52
# 5  _in मुझ भ गुजरा मे 9-9 घंट त बिठाक दिल्ल स आ ए...  2019-02-02 16:53:41
# 6  Arrests CBI Denied permission for rallies Does...  2019-02-03 23:58:55
# 7  Thanks to Namo it seems Dubai Abu Dhabhi no mo...  2019-02-01 23:52:46
# 8  BJP शासि राज्यो समे पूर दे मे बेरोक-टो घूमत है...  2019-02-06 23:56:38
# 9  I want your direct feedback on various issues…...  2019-02-01 23:51:00
#
#    follower_count                                      profile_image  \
# 0             134  https://pbs.twimg.com/profile_images/105806996...
# ...

# %%
ncp = pd.read_csv('old_ncp_all.csv')
ncp.sort_values('retweets', ascending=False, inplace=True)
new_ncp = ncp.drop_duplicates('retweets')[:10]

# %%
new_ncp
# Out:
#                                           cleaned_text           created_at  \
# 894                             _twt ☺️👍💜 #JIMIN #V #풍  2019-01-30 23:46:42
# 846  ก็คือเพื่อนลงสตอรี่แล้วนี่ก็กำลังจะถามว่าไปไห ...  2019-01-31 23:40:48
# 791  ขายของอะใส่ราคาเถอ จะได้ช่วยในการตัดสินใจคือถ้...  2019-01-31 23:56:20
# 871  ในเฟสเหมือนเป็นคนเก็บตั ในไอจีเป็นคนชอบเที่ย ส...  2019-01-31 23:36:10
# 888                      NU'EST WEEK #MINHYUN #NU_WEEK  2019-01-30 23:48:27
# 783  พ่อแม่เลี้ยงเรามาสบายน ไม่เคยต้องอ ของจำเป็นใน...  2019-01-31 23:57:38
# 779  มะกี้ควักสายหูฟังละเหรียญหล่นบนบันไดmrt ผญข้าง...  2019-01-31 23:59:05
# 885  ตอนหมดไฟในการทำงา ก็จะมีพี่ก้องกระซิบเบา ข้างห...  2019-01-30 23:50:09
# 873  _gnow ใครเป็นบ้า บ่นเหี้ยไรลงโซเชี่ย แม่งลงเสร...  2019-01-31 23:35:54
# 811  ประกาศหยุดเรีย แล้วทำไมไม่หยุดงานบ้า คนทำงานไม...  2019-01-31 23:52:44
#
#      follower_count                                      profile_image  \
# ...
